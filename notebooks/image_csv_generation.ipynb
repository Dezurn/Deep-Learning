# %%
import pandas as pd
from pathlib import Path

# %%
train = pd.read_csv('../data/raw/train.csv')
test = pd.read_csv('../data/raw/test.csv')

# %%
IMAGE_DIR_TRAIN = "../data/images/images_train"

# %%
IMAGE_DIR_TEST = "../data/images/images_test"

# %%
train.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
train['image_link'].str.split('/').str[-1].head()
# Out:
# 0    51mo8htwTHL.jpg
# 1    71YtriIHAAL.jpg
# 2    51+PFEe-w-L.jpg
# 3    41mu0HAToDL.jpg
# 4    41sA037+QvL.jpg
# Name: image_link, dtype: object

# %%
train['path'] = IMAGE_DIR_TRAIN + '/' + train['image_link'].str.split('/').str[-1]

# %%
train['path'].head()
# Out:
# 0    ../data/images/images_train/51mo8htwTHL.jpg
# 1    ../data/images/images_train/71YtriIHAAL.jpg
# 2    ../data/images/images_train/51+PFEe-w-L.jpg
# 3    ../data/images/images_train/41mu0HAToDL.jpg
# 4    ../data/images/images_train/41sA037+QvL.jpg
# Name: path, dtype: object

# %%
train.columns
# Out:
# Index(['sample_id', 'catalog_content', 'image_link', 'price', 'path'], dtype='object')

# %%
train = train.drop(columns=['catalog_content','image_link'])

# %%
train.to_csv('../data/for_models/train_for_images.csv')

# %%
test['path'] = IMAGE_DIR_TEST + '/' + test['image_link'].str.split('/').str[-1]
test = test.drop(columns=['catalog_content','image_link'])
test.to_csv('../data/for_models/test_for_images.csv')
